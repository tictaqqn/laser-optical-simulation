# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# from PIL import Image

# %%
circle_vec_dl = pd.read_csv("circle100-100.txt").applymap(lambda s: s.split())
a = list(map(lambda l: np.array(l).astype(float), circle_vec_dl.iloc[:, 0]))
a = np.array(a)
a.shape
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-20-1ea98b384e1d> in <module>
# ----> 1 circle_vec_dl = pd.read_csv("circle100-100.txt").applymap(lambda s: s.split())
#       2 a = list(map(lambda l: np.array(l).astype(float), circle_vec_dl.iloc[:, 0]))
#       3 a = np.array(a)
#       4 a.shape
#
# ...

# %%
# outImg = Image.fromarray(b)
# outImg = outImg.convert("RGB")
# outImg.save("test.png")
plt.imshow(a)

# %%
plt.imshow(np.log(a))

# %%
a

# %%
circle_vec_dl = pd.read_csv("circle1000-100.txt").applymap(lambda s: s.split())
a2 = list(map(lambda l: np.array(l).astype(float), circle_vec_dl.iloc[:, 0]))
a2 = np.array(a2)
a2.shape

# %%
plt.imshow(a2)

# %%
plt.imshow(np.log(a2))

# %%
circle_vec_dl = pd.read_csv("circle100-100-screen5.txt").applymap(lambda s: s.split())
a = list(map(lambda l: np.array(l).astype(float), circle_vec_dl.iloc[:, 0]))
a = np.array(a)
print(a.shape)
plt.imshow(np.log(a))

# %%
circle_vec_dl = pd.read_csv("circle100-100-screen0.5.txt").applymap(lambda s: s.split())
a = list(map(lambda l: np.array(l).astype(float), circle_vec_dl.iloc[:, 0]))
a = np.array(a)
print(a.shape)
plt.imshow(np.log(a))

# %%
# Out:
# src

# %%
circle_vec_dl = pd.read_csv("src/circle100-1000-screen0.5.txt").applymap(lambda s: s.split())
a = list(map(lambda l: np.array(l).astype(float), circle_vec_dl.iloc[:, 0]))
a = np.array(a)
print(a.shape)
plt.imshow(np.log(a))
# Out:
# (1000, 1000)

# %%
circle_vec_dl = pd.read_csv("src/circle100-1000-screen0.5.txt").applymap(lambda s: s.split())
a = list(map(lambda l: np.array(l).astype(float), circle_vec_dl.iloc[:, 0]))
a = np.array(a)
print(a.shape)
plt.imshow(np.log(a))
