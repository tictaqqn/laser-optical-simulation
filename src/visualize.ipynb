# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# from PIL import Image

# %%
circle_vec_dl = pd.read_csv("circle100-100.txt").applymap(lambda s: s.split())
a = list(map(lambda l: np.array(l).astype(float), circle_vec_dl.iloc[:, 0]))
a = np.array(a)
a.shape
# Out:
# (100, 100)

# %%
# outImg = Image.fromarray(b)
# outImg = outImg.convert("RGB")
# outImg.save("test.png")
plt.imshow(a)

# %%
plt.imshow(np.log(a))

# %%
a
# Out:
# array([[1.13628e+02, 2.87973e-01, 1.41347e+01, ..., 1.36881e+01,
#         3.12834e-01, 1.14654e+02],
#        [2.87967e-01, 1.20941e-03, 3.63376e-02, ..., 3.06638e-02,
#         1.10414e-03, 3.24976e-01],
#        [1.41348e+01, 3.63401e-02, 1.78213e+00, ..., 1.73020e+00,
#         3.49095e-02, 1.42141e+01],
#        ...,
#        [1.36881e+01, 3.06608e-02, 1.73020e+00, ..., 1.73163e+00,
#         4.65077e-02, 1.37650e+01],
#        [3.12841e-01, 1.10414e-03, 3.49138e-02, ..., 4.65100e-02,
#         7.57031e-04, 2.99858e-01],
#        [1.14654e+02, 3.24982e-01, 1.42141e+01, ..., 1.37650e+01,
#         2.99854e-01, 1.13628e+02]])

# %%
circle_vec_dl = pd.read_csv("circle1000-100.txt").applymap(lambda s: s.split())
a2 = list(map(lambda l: np.array(l).astype(float), circle_vec_dl.iloc[:, 0]))
a2 = np.array(a2)
a2.shape
# Out:
# (100, 100)

# %%
plt.imshow(a2)

# %%
plt.imshow(np.log(a2))

# %%
circle_vec_dl = pd.read_csv("circle100-100-screen5.txt").applymap(lambda s: s.split())
a = list(map(lambda l: np.array(l).astype(float), circle_vec_dl.iloc[:, 0]))
a = np.array(a)
print(a.shape)
plt.imshow(np.log(a))
# Out:
# (100, 100)

# %%
circle_vec_dl = pd.read_csv("circle100-100-screen0.5.txt").applymap(lambda s: s.split())
a = list(map(lambda l: np.array(l).astype(float), circle_vec_dl.iloc[:, 0]))
a = np.array(a)
print(a.shape)
plt.imshow(np.log(a))
# Out:
# (100, 100)

# %%
circle_vec_dl = pd.read_csv("circle100-1000-screen0.5.txt").applymap(lambda s: s.split())
a = list(map(lambda l: np.array(l).astype(float), circle_vec_dl.iloc[:, 0]))
a = np.array(a)
print(a.shape)
plt.imshow(np.log(a))
# Out:
# (1000, 1000)
